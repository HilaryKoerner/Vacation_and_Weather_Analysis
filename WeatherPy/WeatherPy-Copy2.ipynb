# %% [markdown]
# ### Dependencies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
temp_test = []
city_test = ['chicago', 'miami', 'london', 'xxx']
good_cities = []
for city in city_test:
    response = requests.get(query_url + city).json()
    try:
        temp_test.append(response["main"]["temp"])
        good_cities.append(city)
        print(f"{city} found. Temp appending")
    except KeyError:
        print(f"no temp for {city}")
print(response)
print(temp_test)
print(good_cities)

# %%
ok_cities = []
ok_lat = []
ok_lon = []
ok_maxtemp = []
ok_mintemp = []
ok_humidity = []
ok_clouds = []
ok_wind = []
ok_country = []
ok_date = []

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        ok_cities.append(response["name"])
        ok_lat.append(response["coord"]["lat"])
        ok_lon.append(response["coord"]["lon"])
        ok_maxtemp.append(response["main"]["temp_max"])
        ok_mintemp.append(response["main"]["temp_min"])
        ok_humidity.append(response["main"]["humidity"])
        ok_clouds.append(response["clouds"]["all"])
        ok_wind.append(response["wind"]["speed"])
        ok_country.append(response["sys"]["country"])
        ok_date.append(response["dt"])
        print(f"success appending {city}")
   
    except KeyError:
        print(f"no data found for {city}")
print(response)
# Out:
# success appending bambous virieux
# success appending bam
# success appending adjumani
# success appending rikitea
# no data found for attawapiskat
# success appending coahuayana
# success appending castro
# no data found for vaitupu
# success appending uvarovka
# success appending iqaluit
# success appending bantogon
# success appending yanam
# success appending tiksi
# success appending russell
# success appending konstantinovka
# success appending vanavara
# success appending bonavista
# success appending cherskiy
# success appending hermanus
# success appending nikolskoye
# success appending ushuaia
# success appending sao filipe
# success appending ancud
# success appending saint-philippe
# success appending port-gentil
# success appending reforma
# success appending mataura
# success appending tura
# success appending pangkalanbuun
# success appending east london
# success appending miraflores
# success appending port macquarie
# success appending hobart
# success appending ponta do sol
# success appending nevers
# success appending bluff
# success appending barrow
# success appending georgetown
# success appending beni
# success appending busselton
# success appending kahului
# success appending rognan
# success appending umm kaddadah
# success appending hilo
# success appending longyearbyen
# success appending yellowknife
# success appending port elizabeth
# success appending esperance
# success appending san cristobal
# success appending sisimiut
# success appending adrar
# success appending jamestown
# success appending tasiilaq
# success appending jalingo
# success appending butaritari
# success appending kruisfontein
# success appending kuching
# success appending flin flon
# success appending carnarvon
# success appending odessa
# no data found for illoqqortoormiut
# success appending puerto ayora
# success appending beloha
# success appending tuktoyaktuk
# success appending kushiro
# success appending mar del plata
# success appending samarai
# success appending vila
# success appending albany
# success appending fortuna
# success appending verkh-chebula
# success appending mondeville
# success appending eureka
# success appending walvis bay
# success appending vaini
# success appending namatanai
# no data found for barentsburg
# success appending aklavik
# success appending garachine
# success appending jieshi
# success appending aykhal
# success appending college
# success appending kijini
# success appending swellendam
# success appending abapo
# success appending qaanaaq
# success appending inirida
# success appending broome
# success appending victor harbor
# success appending san quintin
# success appending helong
# success appending kupang
# success appending skelleftea
# success appending thompson
# success appending victoria
# no data found for palabuhanratu
# success appending saint-joseph
# success appending zhaozhou
# success appending lincoln
# success appending kapaa
# success appending macas
# success appending avarua
# success appending bilma
# success appending monywa
# success appending sitka
# success appending turbat
# success appending cidreira
# success appending belton
# success appending padang
# success appending atuona
# no data found for tumannyy
# success appending aksarka
# success appending georgiyevka
# success appending saint-pierre
# success appending portland
# success appending broken hill
# success appending pevek
# success appending pinkafeld
# success appending borazjan
# success appending pacific grove
# success appending nome
# success appending sa kaeo
# no data found for tsihombe
# success appending balkanabat
# success appending cabo san lucas
# success appending virginia beach
# success appending ribeira grande
# success appending torbay
# no data found for samusu
# success appending safita
# success appending hwange
# no data found for taolanaro
# success appending chuy
# success appending bengkulu
# success appending namibe
# success appending saskylakh
# success appending dikson
# success appending kavaratti
# success appending oksfjord
# no data found for mys shmidta
# success appending kodiak
# success appending abu samrah
# success appending bathsheba
# success appending kholmogory
# success appending bestobe
# success appending yerbogachen
# success appending pochutla
# success appending klaksvik
# success appending sembe
# success appending lebu
# success appending ponta delgada
# success appending agadez
# success appending elko
# success appending yulara
# success appending bonthe
# success appending kuala terengganu
# success appending ostrovnoy
# success appending airai
# success appending severo-kurilsk
# success appending wakuya
# success appending cockburn town
# success appending alofi
# success appending caxito
# success appending kovalevskoye
# success appending arraial do cabo
# success appending lapy
# success appending upernavik
# success appending karratha
# success appending hasaki
# success appending riverton
# success appending port alfred
# success appending skreia
# no data found for warqla
# success appending saint-francois
# success appending pemangkat
# success appending faya
# no data found for phnum penh
# success appending khatanga
# success appending punta arenas
# success appending biloli
# success appending hameenlinna
# success appending faanui
# success appending bobo dioulasso
# success appending karangsembung
# success appending halmaj
# success appending xining
# success appending leningradskiy
# success appending ilulissat
# success appending qarqin
# success appending saint george
# success appending acari
# success appending praia da vitoria
# success appending hami
# success appending comodoro rivadavia
# success appending bethel
# success appending kloulklubed
# success appending gamba
# success appending tambun
# success appending dombas
# success appending orebro
# success appending chokurdakh
# success appending progreso
# success appending barranca
# success appending mahenge
# success appending yarada
# success appending itzehoe
# success appending puerto madero
# no data found for grand river south east
# success appending palagiano
# success appending halifax
# success appending avera
# success appending saurimo
# success appending mount isa
# no data found for nizhneyansk
# success appending toccoa
# success appending totoro
# success appending troitsko-pechorsk
# success appending provideniya
# success appending yinchuan
# success appending bredasdorp
# success appending hede
# success appending tame
# success appending carauari
# success appending lavrentiya
# success appending goderich
# success appending nadym
# success appending baykit
# success appending camacha
# success appending port hardy
# success appending jibuti
# success appending kampot
# success appending lufilufi
# success appending shingu
# success appending cheney
# success appending gravdal
# success appending alamosa
# success appending flinders
# success appending sioux lookout
# success appending richards bay
# success appending japura
# success appending cape town
# success appending sharya
# success appending gizo
# success appending codrington
# success appending santa maria
# success appending portree
# success appending rincon
# success appending matara
# success appending mackay
# success appending ferrol
# success appending lorengau
# success appending new norfolk
# success appending ixtapa
# success appending provost
# success appending melk
# success appending lagos
# success appending atambua
# success appending branisca
# success appending rantepao
# success appending knysna
# success appending nishihara
# success appending yunguyo
# success appending hamilton
# success appending waipawa
# success appending dingle
# no data found for sentyabrskiy
# success appending los llanos de aridane
# success appending champerico
# success appending santa ines
# success appending vardo
# success appending pangnirtung
# success appending saldanha
# success appending mayo
# success appending srednekolymsk
# success appending huilong
# success appending lugoba
# no data found for marcona
# success appending caohai
# success appending alyangula
# success appending basco
# success appending burns lake
# success appending kashin
# success appending hithadhoo
# success appending arys
# success appending juneau
# success appending quimper
# success appending inongo
# success appending xilagani
# success appending naka
# success appending songea
# success appending san bartolome de tirajana
# success appending sur
# success appending hit
# success appending toyooka
# success appending luena
# success appending uvalde
# success appending rawson
# success appending tuatapere
# success appending iskateley
# success appending sabang
# success appending mogadishu
# success appending baruun-urt
# success appending poum
# success appending kaitangata
# success appending chincha alta
# no data found for lolua
# success appending asau
# no data found for belushya guba
# success appending kasangulu
# success appending peniche
# success appending kyrnasivka
# success appending te anau
# no data found for imisli
# success appending ohara
# success appending voyvozh
# success appending campos do jordao
# success appending teguise
# success appending vila franca do campo
# success appending kavieng
# success appending bilgoraj
# success appending marzuq
# success appending dakar
# success appending mataram
# success appending parkes
# success appending paamiut
# success appending puerto del rosario
# success appending lompoc
# success appending dunedin
# success appending isangel
# success appending deputatskiy
# success appending tazovskiy
# success appending moree
# success appending aracaju
# success appending kaka
# success appending aksu
# success appending maragogi
# success appending nuuk
# success appending nioro
# success appending cassilandia
# success appending port hedland
# success appending anadyr
# no data found for umzimvubu
# success appending darnah
# success appending batagay-alyta
# success appending axim
# success appending narsaq
# success appending ayabaca
# success appending quatre cocos
# success appending lucapa
# success appending souillac
# success appending benatky nad jizerou
# success appending wanning
# success appending tilichiki
# success appending kikwit
# success appending starobachaty
# success appending la rioja
# no data found for bo
# success appending leh
# success appending iquitos
# success appending maputo
# success appending carmaux
# success appending surt
# success appending valparaiso
# success appending tygda
# success appending chimore
# success appending aitape
# success appending najran
# success appending grosse pointe farms
# success appending tanout
# success appending okhotsk
# success appending mandera
# success appending labuhan
# success appending labateca
# success appending magadan
# success appending cedar rapids
# success appending ngunguru
# success appending boguchar
# success appending maceio
# success appending derzhavinsk
# success appending starkville
# success appending atar
# success appending belmonte
# success appending kroya
# success appending alta floresta
# success appending hofn
# no data found for tawkar
# no data found for tidore
# success appending zonguldak
# success appending suntar
# success appending mount gambier
# success appending salalah
# success appending willmar
# success appending takoradi
# success appending plettenberg bay
# success appending beyneu
# success appending kondinskoye
# success appending starozhilovo
# success appending matagami
# success appending sarangani
# no data found for bokspits
# success appending poshekhonye
# success appending nanortalik
# success appending san rafael
# success appending olafsvik
# success appending kirakira
# success appending san patricio
# success appending halmstad
# success appending alcoa
# success appending jais
# success appending mbini
# success appending dicabisagan
# success appending ampanihy
# success appending sassandra
# success appending ntcheu
# success appending guerrero negro
# success appending port shepstone
# success appending sao joao da barra
# success appending mahebourg
# no data found for temaraia
# success appending ust-maya
# success appending erdenet
# success appending marsaxlokk
# success appending tarata
# success appending itarema
# success appending vondrozo
# no data found for macaboboni
# success appending penarroya-pueblonuevo
# success appending fort nelson
# no data found for ust-kamchatsk
# success appending manzhouli
# success appending rocha
# success appending pangai
# success appending ust-koksa
# success appending nago
# success appending takab
# success appending odweyne
# success appending kozhva
# success appending svetlaya
# success appending pangody
# no data found for kawana waters
# success appending lombardia
# success appending manjacaze
# success appending tulsipur
# success appending shalinskoye
# success appending constitucion
# success appending abu kamal
# success appending nichinan
# success appending madimba
# success appending kalang
# success appending caravelas
# success appending botwood
# no data found for ruatoria
# success appending azul
# success appending san juan de uraba
# success appending san pedro
# success appending seymchan
# success appending ginda
# success appending nehe
# success appending wilmington
# success appending kaeo
# no data found for azimur
# success appending manica
# no data found for amderma
# success appending brawley
# success appending ravar
# success appending hlukhiv
# success appending clyde river
# success appending pestretsy
# success appending san roque
# success appending castanheira de pera
# success appending muroto
# success appending markova
# success appending sao geraldo do araguaia
# success appending griffith
# success appending teya
# success appending jining
# success appending price
# success appending port lincoln
# success appending skiathos
# success appending bonfim
# success appending ambon
# success appending talnakh
# success appending naze
# success appending ulladulla
# success appending gushikawa
# success appending marawi
# success appending hammerfest
# success appending makakilo city
# success appending lagoa
# success appending norman wells
# success appending mombasa
# success appending roald
# success appending shu
# success appending olinda
# success appending monsenhor gil
# success appending araceli
# no data found for karaul
# success appending santa cruz de tenerife
# success appending coihaique
# success appending methoni
# success appending honiara
# no data found for gardan diwal
# success appending krasnovishersk
# no data found for naftah
# success appending wawa
# success appending yei
# no data found for samalaeulu
# no data found for paucartambo
# success appending calama
# success appending trat
# success appending seydisehir
# success appending sampit
# success appending kosh-agach
# success appending lata
# success appending taltal
# success appending san jeronimo
# success appending upata
# success appending werkendam
# no data found for dianopolis
# success appending rabo de peixe
# success appending baculin
# success appending chicama
# success appending luau
# success appending north bend
# success appending balakhta
# success appending borger
# no data found for kuche
# success appending sangar
# success appending husavik
# success appending uzyn
# success appending ahipara
# success appending batagay
# success appending tadine
# success appending petropavlovsk-kamchatskiy
# success appending taikang
# no data found for chagda
# success appending vostok
# success appending mundi
# success appending acapulco
# success appending pisco
# no data found for tome-acu
# success appending redlands
# success appending port blair
# no data found for taburi
# success appending newport
# success appending storm lake
# success appending ugrinovci
# success appending ust-nera
# success appending half moon bay
# success appending petilia policastro
# success appending sirnak
# success appending taft
# success appending palmer
# success appending natal
# success appending araouane
# success appending katsuura
# success appending nakamura
# success appending kita
# success appending carlyle
# success appending stettler
# success appending goya
# success appending bendigo
# success appending acton
# success appending buin
# success appending wajima
# success appending vao
# success appending petatlan
# success appending miami
# success appending lubango
# success appending pokhara
# success appending meulaboh
# success appending michigan city
# success appending mangan
# success appending kodinsk
# success appending apartado
# success appending turan
# success appending puerto ayacucho
# success appending hovd
# success appending saint-augustin
# success appending pahrump
# success appending vestmannaeyjar
# success appending izvestkovyy
# success appending mocuba
# success appending fairbanks
# success appending tiznit
# success appending mwanza
# success appending atikokan
# success appending mayor pablo lagerenza
# success appending anton lizardo
# success appending grindavik
# success appending quelimane
# success appending fengzhen
# no data found for chhukha
# success appending poronaysk
# success appending morondava
# success appending abay
# success appending sujiatun
# success appending maniitsoq
# no data found for saleaula
# success appending chandur
# success appending khawhai
# success appending buritizeiro
# success appending amatitan
# success appending saint-georges
# success appending smithers
# success appending dalby
# success appending hambantota
# success appending two hills
# success appending camana
# success appending beterou
# success appending freeport
# success appending bandarbeyla
# success appending buala
# success appending neuquen
# {'coord': {'lon': -68.0591, 'lat': -38.9516}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 71.6, 'feels_like': 64.38, 'temp_min': 71.6, 'temp_max': 71.6, 'pressure': 1012, 'humidity': 33}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 250}, 'clouds': {'all': 0}, 'dt': 1611718221, 'sys': {'type': 1, 'id': 8310, 'country': 'AR', 'sunrise': 1611740281, 'sunset': 1611791510}, 'timezone': -10800, 'id': 3843123, 'name': 'Neuquén', 'cod': 200}

# %%
print(len(ok_cities))
print(len(ok_lat))
print(len(ok_lon))
print(len(ok_maxtemp))
print(len(ok_mintemp))
print(len(ok_humidity))
print(len(ok_clouds))
print(len(ok_wind))
print(len(ok_country))
print(len(ok_date))

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
weather_dict = {"City": ok_cities, "Latitude": ok_lat, "Longitude": ok_lon, "Max Temp": ok_maxtemp, 
                "Humidity": ok_humidity, "Cloudiness": ok_clouds, "Wind Speed": ok_wind, 
                "Country": ok_country, "Date": ok_date}

weather_df = pd.DataFrame(weather_dict)
weather_df

# %% [markdown]
# ### Inspect data and remove cities where the humidty is > 100%

# %%
low_hum = pd.DataFrame(weather_df[weather_df["Humidity"]< 100])
low_hum

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
plot_lat = low_hum_df['Latitude']
plot_temp = low_hum_df["Max Temp"]

plt.scatter(plot_lat, plot_temp, marker="o", facecolors = "blue", edgecolors="black", 
            alpha=.99)

plt.grid(color="grey", linestyle="-", linewidth=1)
plt.title("Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")

# %% [markdown]
# ### Latitude vs. Humidty Plot

# %%
plot_lat = low_hum_df['Latitude']
plot_humidity = low_hum_df["Humidity"]

plt.scatter(plot_lat, plot_humidity, marker="o", facecolors = "blue", edgecolors="black", 
            alpha=.99)

plt.grid(color="grey", linestyle="-", linewidth=1)
plt.title(f"Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
plot_lat = low_hum_df['Latitude']
plot_cloud = low_hum_df["Cloudiness"]

plt.scatter(plot_lat, plot_cloud, marker="o", facecolors = "blue", edgecolors="black", 
            alpha=.99)

plt.grid(color="grey", linestyle="-", linewidth=.1)
plt.title(f"Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# %% [markdown]
# ###  Latitude vs. Wind Speed Plot

# %%
plot_lat = low_hum_df['Latitude']
plot_wind = low_hum_df["Wind Speed"]

plt.scatter(plot_lat, plot_wind, marker="o", facecolors = "blue", edgecolors="black", 
            alpha=.99)

plt.grid(color="grey", linestyle="-", linewidth=.5)
plt.title(f"Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# %% [markdown]
# ## Linear Regression

# %%
north_hem = pd.DataFrame(low_hum[low_hum["Latitude"]> 0])
north_hem.head()

# %%
north_lat = north_hem["Latitude"]
north_maxtemp = north_hem["Max Temp"]
north_humid = north_hem["Humidity"]
north_cloud = north_hem["Cloudiness"]
north_wind = north_hem["Wind Speed"]

# %%
south_hem = pd.DataFrame(low_hum[low_hum["Latitude"]< 0])
south_hem.head()

# %%
south_lat = south_hem["Latitude"]
south_maxtemp = south_hem["Max Temp"]
south_humid = south_hem["Humidity"]
south_cloud = south_hem["Cloudiness"]
south_wind = south_hem["Wind Speed"]

# %% [markdown]
# ### Northern Hemisphere: Max Temp vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(north_lat, north_maxtemp)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(north_lat, north_maxtemp)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_lat, north_maxtemp)
plt.plot(north_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere: Latitude vs. Max Temp")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Southern Hemisphere: Max Temp vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(south_lat, south_maxtemp)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(south_lat, south_maxtemp)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_maxtemp)
plt.plot(south_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere: Latitude vs. Max Temp")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Northern Hemisphere: Humidty (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(north_lat, north_humid)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(north_lat, north_humid)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_lat, north_humid)
plt.plot(north_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Latitude vs. Humidity")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Southern Hemisphere: Humidty (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(south_lat, south_humid)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(south_lat, south_humid)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_humid)
plt.plot(south_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere: Latitude vs. Humidity")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Northern Hemisphere: Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(north_lat, north_cloud)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(north_lat, north_cloud)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_lat, north_cloud)
plt.plot(north_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Latitude vs. Cloudiness")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Southern Hemisphere: Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(south_lat, south_cloud)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(south_lat, south_cloud)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_cloud)
plt.plot(south_lat,regress_values, "r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere Latitude vs. Cloudiness")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Northern Hemisphere: Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(north_lat, north_wind)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(north_lat, north_wind)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_lat, north_wind)
plt.plot(north_lat,regress_values, "r-")
# plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Nortern Hemisphere: Latitude vs. Wind Speed")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()

# %% [markdown]
# ### Southern Hemisphere: Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(south_lat, south_wind)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(south_lat, south_wind)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_wind)
plt.plot(south_lat,regress_values, "r-")
# plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere: Latitude vs. Wind Speed")
print(f"The r-value is {round(correlation[0],2)}")
plt.show()
